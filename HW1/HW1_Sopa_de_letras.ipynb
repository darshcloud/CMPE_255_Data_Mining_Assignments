# %% [markdown]
# `CMPE-255. Fall 2023`
#
# # Sopa de Letras
# Also known as "Word Search Puzzle", this game consists of the letters of words placed in a grid. The objective of this puzzle is to find all the words hidden inside the grid.

# %%
# Libraries - ONLY THIS LIBRARIES ARE ALLOWED FOR THE HOMEWORK
import numpy as np
import pandas as pd
import random
import sys
# Do not add any other library

# %%
# Soup size
DIMENSIONS = (8, 8)
# Word to insert in the soup
WORD = "MINING"
#Words to insert in the thick soup
WORDS = ["DATA", "MINING", "SJSU"]
# English alphabet
ALPHABET = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %%
def create_random_broth(dimensions, alphabet):
  '''Create a random soup of letters.
  Return the soup as a n-dimensional array

  dimensions: Tuple with dimensions. E.g., (8, 8, 8) for a 3-D 8x8x8 array
  alphabet  : String with alphabet to use for letters in the broth
  '''

  # Create a multi-dimentional array of random numbers
  a = np.random.randint(0, len(alphabet)-1, dimensions)
  # Swap numbers in the array with characters from the alphabet
  my_dict = dict(zip(range(len(alphabet)), list(alphabet)))
  broth = np.vectorize(my_dict.get)(a)

  return broth

# %%
def add_word_to_broth(broth, word):
  '''Add "word" at random locations.
       Return the updated soup'''

  msoup = broth.copy()
  dimensions = broth.shape
  word_length = len(word)
  # Words are inserted as "lowercase", so it's easy to check
  not_suitable = True
  # Check if the randomly-selected insertion point is feasible
  max_attempts = 100
  while (not_suitable):
    max_attempts -= 1
    if (max_attempts == 0):
      print("ERROR - Unable to add word, after 100 attempts")
      return []
    # Pick a random start point
    start_point = [0] * len(dimensions)
    for i in range(len(dimensions)):
      start_point[i] = np.random.randint(0, dimensions[i])
    end_point = start_point.copy()
    # Pick a random dimension to place the word
    dim = np.random.randint(0, len(dimensions))
    # Calculate the end point of the word along the selected dimension
    end_point[dim] = start_point[dim] + len(word) - 1
    # Calculate the indexes in the array that the word would use when placed
    idx_increment = [0] * len(dimensions)
    idx_increment[dim] = 1
    indexes = [[start_point[j] + i*idx_increment[j] for j in range(len(start_point))] for i in range(len(word))]

    # Check if the word fits in the selected dimension
    if end_point[dim] >= dimensions[dim]:
      continue
    # Check if there is already a word (inserted words are always lowercase)
    c = [msoup[tuple(index)] for index in indexes]
    s = ''.join(c)
    if not s.isupper():
      continue

    # Add word
    for i in range(len(indexes)):
      msoup[tuple(indexes[i])] = word[i].lower()

    # Done with word
    not_suitable = False

  return np.char.upper(msoup)

# %%
def create_soup (dimensions, word, alphabet):
    '''Create a n-dimensional matrix of random letters (broth),
       then add words to it to make a soup.
       Return the soup'''

    broth = create_random_broth(dimensions, alphabet)
    soup  = add_word_to_broth(broth, word)
    return soup

# %%
def serve_soup(soup_plate, locations):
  '''Return highlighted DataFrame ready for display.
  rows and columns are subsets of the dataframe. For instance:
  rows = [2], cols = slice(1,6) - Highlight cells in row 2, from column 1 to 5
  '''
  styler = soup_plate.style
  styler.set_properties(**{'text-align': 'center'})
  for (rows, cols) in locations:
    styler.set_properties(subset=(rows, cols), **{'background': 'yellow'})

  return styler

# %%
def find_word_in_plate(word, soup_plate):
  '''Find a word in a 2-dimensional Pandas DataFrame'''

  result = []
  for icol in soup_plate.columns:
    for irow, row in soup_plate.iterrows():
      r = is_word_at_location(word, irow, icol, soup_plate)
      if r == 'h':
        result.append(([irow], slice(icol, icol+len(word)-1)))
      if r == 'v':
        result.append((slice(irow, irow+len(word)-1), [icol]))

  return result


def is_word_at_location(word, irow, icol, soup_plate):
  '''Examine a DataFrame at location (row, col) and
  determine if there is a "word"'''

  word_size = len(word)

  h_size = len(soup_plate.columns) - icol
  v_size = len(soup_plate.index) - irow

  # Check Horizontal
  if h_size >= word_size:
    res = True
    for i in range(len(word)):
      if soup_plate.iloc[irow, icol+i].upper() != word[i].upper(): res = False
    if res: return 'h'

  # Check Vertical
  if v_size >= word_size:
    res = True
    for i in range(len(word)):
      if soup_plate.iloc[irow+i, icol].upper() != word[i].upper(): res = False
    if res: return 'v'

  return ''

# %%
# Example 1 - Create a 8x8 puzzle, and insert the word "MINING".
# Find the word and display
# %%time
s = create_soup((8,8), 'MINING', ALPHABET)
sl = slice(0, 8)
spoon = (sl, sl)
plate = pd.DataFrame(s[spoon])
words = find_word_in_plate("MINING", plate)
print(words)
table = serve_soup(plate, words)
table
# Out:
# [([7], slice(2, 7, None))]
# CPU times: user 79.2 ms, sys: 2.05 ms, total: 81.3 ms
# Wall time: 96.4 ms
# <style type="text/css">
# #T_7a5dc_row0_col0, #T_7a5dc_row0_col1, #T_7a5dc_row0_col2, #T_7a5dc_row0_col3, #T_7a5dc_row0_col4, #T_7a5dc_row0_col5, #T_7a5dc_row0_col6, #T_7a5dc_row0_col7, #T_7a5dc_row1_col0, #T_7a5dc_row1_col1, #T_7a5dc_row1_col2, #T_7a5dc_row1_col3, #T_7a5dc_row1_col4, #T_7a5dc_row1_col5, #T_7a5dc_row1_col6, #T_7a5dc_row1_col7, #T_7a5dc_row2_col0, #T_7a5dc_row2_col1, #T_7a5dc_row2_col2, #T_7a5dc_row2_col3, #T_7a5dc_row2_col4, #T_7a5dc_row2_col5, #T_7a5dc_row2_col6, #T_7a5dc_row2_col7, #T_7a5dc_row3_col0, #T_7a5dc_row3_col1, #T_7a5dc_row3_col2, #T_7a5dc_row3_col3, #T_7a5dc_row3_col4, #T_7a5dc_row3_col5, #T_7a5dc_row3_col6, #T_7a5dc_row3_col7, #T_7a5dc_row4_col0, #T_7a5dc_row4_col1, #T_7a5dc_row4_col2, #T_7a5dc_row4_col3, #T_7a5dc_row4_col4, #T_7a5dc_row4_col5, #T_7a5dc_row4_col6, #T_7a5dc_row4_col7, #T_7a5dc_row5_col0, #T_7a5dc_row5_col1, #T_7a5dc_row5_col2, #T_7a5dc_row5_col3, #T_7a5dc_row5_col4, #T_7a5dc_row5_col5, #T_7a5dc_row5_col6, #T_7a5dc_row5_col7, #T_7a5dc_row6_col0, #T_7a5dc_row6_col1, #T_7a5dc_row6_col2, #T_7a5dc_row6_col3, #T_7a5dc_row6_col4, #T_7a5dc_row6_col5, #T_7a5dc_row6_col6, #T_7a5dc_row6_col7, #T_7a5dc_row7_col0, #T_7a5dc_row7_col1 {
#   text-align: center;
# }
# #T_7a5dc_row7_col2, #T_7a5dc_row7_col3, #T_7a5dc_row7_col4, #T_7a5dc_row7_col5, #T_7a5dc_row7_col6, #T_7a5dc_row7_col7 {
#   text-align: center;
#   background: yellow;
# }
# </style>
# <table id="T_7a5dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a5dc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7a5dc_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7a5dc_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7a5dc_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_7a5dc_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_7a5dc_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_7a5dc_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_7a5dc_level0_col7" class="col_heading level0 col7" >7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a5dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a5dc_row0_col0" class="data row0 col0" >W</td>
#       <td id="T_7a5dc_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_7a5dc_row0_col2" class="data row0 col2" >I</td>
#       <td id="T_7a5dc_row0_col3" class="data row0 col3" >L</td>
#       <td id="T_7a5dc_row0_col4" class="data row0 col4" >Y</td>
#       <td id="T_7a5dc_row0_col5" class="data row0 col5" >D</td>
#       <td id="T_7a5dc_row0_col6" class="data row0 col6" >V</td>
#       <td id="T_7a5dc_row0_col7" class="data row0 col7" >B</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a5dc_row1_col0" class="data row1 col0" >O</td>
#       <td id="T_7a5dc_row1_col1" class="data row1 col1" >I</td>
#       <td id="T_7a5dc_row1_col2" class="data row1 col2" >H</td>
#       <td id="T_7a5dc_row1_col3" class="data row1 col3" >W</td>
#       <td id="T_7a5dc_row1_col4" class="data row1 col4" >T</td>
#       <td id="T_7a5dc_row1_col5" class="data row1 col5" >W</td>
#       <td id="T_7a5dc_row1_col6" class="data row1 col6" >P</td>
#       <td id="T_7a5dc_row1_col7" class="data row1 col7" >U</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a5dc_row2_col0" class="data row2 col0" >U</td>
#       <td id="T_7a5dc_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_7a5dc_row2_col2" class="data row2 col2" >O</td>
#       <td id="T_7a5dc_row2_col3" class="data row2 col3" >S</td>
#       <td id="T_7a5dc_row2_col4" class="data row2 col4" >D</td>
#       <td id="T_7a5dc_row2_col5" class="data row2 col5" >E</td>
#       <td id="T_7a5dc_row2_col6" class="data row2 col6" >X</td>
#       <td id="T_7a5dc_row2_col7" class="data row2 col7" >G</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a5dc_row3_col0" class="data row3 col0" >G</td>
#       <td id="T_7a5dc_row3_col1" class="data row3 col1" >E</td>
#       <td id="T_7a5dc_row3_col2" class="data row3 col2" >W</td>
#       <td id="T_7a5dc_row3_col3" class="data row3 col3" >C</td>
#       <td id="T_7a5dc_row3_col4" class="data row3 col4" >M</td>
#       <td id="T_7a5dc_row3_col5" class="data row3 col5" >K</td>
#       <td id="T_7a5dc_row3_col6" class="data row3 col6" >M</td>
#       <td id="T_7a5dc_row3_col7" class="data row3 col7" >K</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a5dc_row4_col0" class="data row4 col0" >R</td>
#       <td id="T_7a5dc_row4_col1" class="data row4 col1" >X</td>
#       <td id="T_7a5dc_row4_col2" class="data row4 col2" >E</td>
#       <td id="T_7a5dc_row4_col3" class="data row4 col3" >E</td>
#       <td id="T_7a5dc_row4_col4" class="data row4 col4" >J</td>
#       <td id="T_7a5dc_row4_col5" class="data row4 col5" >A</td>
#       <td id="T_7a5dc_row4_col6" class="data row4 col6" >L</td>
#       <td id="T_7a5dc_row4_col7" class="data row4 col7" >X</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a5dc_row5_col0" class="data row5 col0" >N</td>
#       <td id="T_7a5dc_row5_col1" class="data row5 col1" >Y</td>
#       <td id="T_7a5dc_row5_col2" class="data row5 col2" >A</td>
#       <td id="T_7a5dc_row5_col3" class="data row5 col3" >B</td>
#       <td id="T_7a5dc_row5_col4" class="data row5 col4" >U</td>
#       <td id="T_7a5dc_row5_col5" class="data row5 col5" >D</td>
#       <td id="T_7a5dc_row5_col6" class="data row5 col6" >S</td>
#       <td id="T_7a5dc_row5_col7" class="data row5 col7" >G</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a5dc_row6_col0" class="data row6 col0" >W</td>
#       <td id="T_7a5dc_row6_col1" class="data row6 col1" >U</td>
#       <td id="T_7a5dc_row6_col2" class="data row6 col2" >S</td>
#       <td id="T_7a5dc_row6_col3" class="data row6 col3" >H</td>
#       <td id="T_7a5dc_row6_col4" class="data row6 col4" >A</td>
#       <td id="T_7a5dc_row6_col5" class="data row6 col5" >L</td>
#       <td id="T_7a5dc_row6_col6" class="data row6 col6" >J</td>
#       <td id="T_7a5dc_row6_col7" class="data row6 col7" >P</td>
#     </tr>
#     <tr>
#       <th id="T_7a5dc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a5dc_row7_col0" class="data row7 col0" >R</td>
#       <td id="T_7a5dc_row7_col1" class="data row7 col1" >H</td>
#       <td id="T_7a5dc_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_7a5dc_row7_col3" class="data row7 col3" >I</td>
#       <td id="T_7a5dc_row7_col4" class="data row7 col4" >N</td>
#       <td id="T_7a5dc_row7_col5" class="data row7 col5" >I</td>
#       <td id="T_7a5dc_row7_col6" class="data row7 col6" >N</td>
#       <td id="T_7a5dc_row7_col7" class="data row7 col7" >G</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Example 2 - Create a 8 x 8 x 4 puzzle, and insert the word "MINING"
# Create a plate (2-d dataframe), and check if the word is there
# %%time
s = create_soup((8,8, 4), 'MINING', ALPHABET)
sl = slice(0, 8)
spoon = (sl, sl, 0)
plate = pd.DataFrame(s[spoon])
words = find_word_in_plate("MINING", plate)
print(words)
table = serve_soup(plate, words)
table
# Out:
# []
# CPU times: user 11.7 ms, sys: 890 µs, total: 12.6 ms
# Wall time: 13.4 ms
# <style type="text/css">
# #T_e18ad_row0_col0, #T_e18ad_row0_col1, #T_e18ad_row0_col2, #T_e18ad_row0_col3, #T_e18ad_row0_col4, #T_e18ad_row0_col5, #T_e18ad_row0_col6, #T_e18ad_row0_col7, #T_e18ad_row1_col0, #T_e18ad_row1_col1, #T_e18ad_row1_col2, #T_e18ad_row1_col3, #T_e18ad_row1_col4, #T_e18ad_row1_col5, #T_e18ad_row1_col6, #T_e18ad_row1_col7, #T_e18ad_row2_col0, #T_e18ad_row2_col1, #T_e18ad_row2_col2, #T_e18ad_row2_col3, #T_e18ad_row2_col4, #T_e18ad_row2_col5, #T_e18ad_row2_col6, #T_e18ad_row2_col7, #T_e18ad_row3_col0, #T_e18ad_row3_col1, #T_e18ad_row3_col2, #T_e18ad_row3_col3, #T_e18ad_row3_col4, #T_e18ad_row3_col5, #T_e18ad_row3_col6, #T_e18ad_row3_col7, #T_e18ad_row4_col0, #T_e18ad_row4_col1, #T_e18ad_row4_col2, #T_e18ad_row4_col3, #T_e18ad_row4_col4, #T_e18ad_row4_col5, #T_e18ad_row4_col6, #T_e18ad_row4_col7, #T_e18ad_row5_col0, #T_e18ad_row5_col1, #T_e18ad_row5_col2, #T_e18ad_row5_col3, #T_e18ad_row5_col4, #T_e18ad_row5_col5, #T_e18ad_row5_col6, #T_e18ad_row5_col7, #T_e18ad_row6_col0, #T_e18ad_row6_col1, #T_e18ad_row6_col2, #T_e18ad_row6_col3, #T_e18ad_row6_col4, #T_e18ad_row6_col5, #T_e18ad_row6_col6, #T_e18ad_row6_col7, #T_e18ad_row7_col0, #T_e18ad_row7_col1, #T_e18ad_row7_col2, #T_e18ad_row7_col3, #T_e18ad_row7_col4, #T_e18ad_row7_col5, #T_e18ad_row7_col6, #T_e18ad_row7_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_e18ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e18ad_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e18ad_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e18ad_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e18ad_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e18ad_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_e18ad_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_e18ad_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_e18ad_level0_col7" class="col_heading level0 col7" >7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e18ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e18ad_row0_col0" class="data row0 col0" >G</td>
#       <td id="T_e18ad_row0_col1" class="data row0 col1" >P</td>
#       <td id="T_e18ad_row0_col2" class="data row0 col2" >F</td>
#       <td id="T_e18ad_row0_col3" class="data row0 col3" >E</td>
#       <td id="T_e18ad_row0_col4" class="data row0 col4" >J</td>
#       <td id="T_e18ad_row0_col5" class="data row0 col5" >B</td>
#       <td id="T_e18ad_row0_col6" class="data row0 col6" >H</td>
#       <td id="T_e18ad_row0_col7" class="data row0 col7" >B</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e18ad_row1_col0" class="data row1 col0" >Q</td>
#       <td id="T_e18ad_row1_col1" class="data row1 col1" >J</td>
#       <td id="T_e18ad_row1_col2" class="data row1 col2" >L</td>
#       <td id="T_e18ad_row1_col3" class="data row1 col3" >E</td>
#       <td id="T_e18ad_row1_col4" class="data row1 col4" >A</td>
#       <td id="T_e18ad_row1_col5" class="data row1 col5" >I</td>
#       <td id="T_e18ad_row1_col6" class="data row1 col6" >O</td>
#       <td id="T_e18ad_row1_col7" class="data row1 col7" >F</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e18ad_row2_col0" class="data row2 col0" >V</td>
#       <td id="T_e18ad_row2_col1" class="data row2 col1" >K</td>
#       <td id="T_e18ad_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_e18ad_row2_col3" class="data row2 col3" >T</td>
#       <td id="T_e18ad_row2_col4" class="data row2 col4" >Y</td>
#       <td id="T_e18ad_row2_col5" class="data row2 col5" >E</td>
#       <td id="T_e18ad_row2_col6" class="data row2 col6" >H</td>
#       <td id="T_e18ad_row2_col7" class="data row2 col7" >G</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e18ad_row3_col0" class="data row3 col0" >M</td>
#       <td id="T_e18ad_row3_col1" class="data row3 col1" >S</td>
#       <td id="T_e18ad_row3_col2" class="data row3 col2" >S</td>
#       <td id="T_e18ad_row3_col3" class="data row3 col3" >F</td>
#       <td id="T_e18ad_row3_col4" class="data row3 col4" >Y</td>
#       <td id="T_e18ad_row3_col5" class="data row3 col5" >T</td>
#       <td id="T_e18ad_row3_col6" class="data row3 col6" >W</td>
#       <td id="T_e18ad_row3_col7" class="data row3 col7" >R</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e18ad_row4_col0" class="data row4 col0" >T</td>
#       <td id="T_e18ad_row4_col1" class="data row4 col1" >P</td>
#       <td id="T_e18ad_row4_col2" class="data row4 col2" >B</td>
#       <td id="T_e18ad_row4_col3" class="data row4 col3" >I</td>
#       <td id="T_e18ad_row4_col4" class="data row4 col4" >H</td>
#       <td id="T_e18ad_row4_col5" class="data row4 col5" >A</td>
#       <td id="T_e18ad_row4_col6" class="data row4 col6" >T</td>
#       <td id="T_e18ad_row4_col7" class="data row4 col7" >N</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e18ad_row5_col0" class="data row5 col0" >D</td>
#       <td id="T_e18ad_row5_col1" class="data row5 col1" >T</td>
#       <td id="T_e18ad_row5_col2" class="data row5 col2" >S</td>
#       <td id="T_e18ad_row5_col3" class="data row5 col3" >B</td>
#       <td id="T_e18ad_row5_col4" class="data row5 col4" >Q</td>
#       <td id="T_e18ad_row5_col5" class="data row5 col5" >G</td>
#       <td id="T_e18ad_row5_col6" class="data row5 col6" >Q</td>
#       <td id="T_e18ad_row5_col7" class="data row5 col7" >V</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e18ad_row6_col0" class="data row6 col0" >T</td>
#       <td id="T_e18ad_row6_col1" class="data row6 col1" >W</td>
#       <td id="T_e18ad_row6_col2" class="data row6 col2" >V</td>
#       <td id="T_e18ad_row6_col3" class="data row6 col3" >L</td>
#       <td id="T_e18ad_row6_col4" class="data row6 col4" >V</td>
#       <td id="T_e18ad_row6_col5" class="data row6 col5" >N</td>
#       <td id="T_e18ad_row6_col6" class="data row6 col6" >R</td>
#       <td id="T_e18ad_row6_col7" class="data row6 col7" >A</td>
#     </tr>
#     <tr>
#       <th id="T_e18ad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e18ad_row7_col0" class="data row7 col0" >O</td>
#       <td id="T_e18ad_row7_col1" class="data row7 col1" >B</td>
#       <td id="T_e18ad_row7_col2" class="data row7 col2" >I</td>
#       <td id="T_e18ad_row7_col3" class="data row7 col3" >K</td>
#       <td id="T_e18ad_row7_col4" class="data row7 col4" >F</td>
#       <td id="T_e18ad_row7_col5" class="data row7 col5" >T</td>
#       <td id="T_e18ad_row7_col6" class="data row7 col6" >N</td>
#       <td id="T_e18ad_row7_col7" class="data row7 col7" >E</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Homework Solution

# %% [markdown]
# ## Deliverable 1
# Setup Google Colab and run the provided notebook and example.
# Add support for inserting multiple words in a puzzle. In order to do that, create two new functions:
#
# ```
# add_words_to_broth(broth, words)
# create_thick_soup(dimensions, words, alphabet)
# ```
# The first function (add_words_to_broth) adds multiple words. Its argument "words" is a list of words in the form "["WORD1", "WORD2", ...].
# The second function (create_thick_soup) uses "add_words_to_broth" to create a puzzle with multiple words inserted.
#
# Create a 2-dimensional 16x16 soup with the following words added "DATA", "MINING", "SJSU", and display the results.

# %%
def add_words_to_broth(broth, words):
    '''Add multiple words to the soup'''
    msoup = broth.copy()
    for word in words:
        msoup = add_word_to_broth(msoup, word)
    return msoup

# %%
def create_thick_soup (dimensions, words, alphabet):
    '''Create a 16 x 16 puzzle with multiple words inserted'''
    broth = create_random_broth(dimensions, alphabet)
    soup  = add_words_to_broth(broth, words)
    return soup

# %%
# %%time
dimensions = (16, 16)
s = create_thick_soup(dimensions, WORDS, ALPHABET)
spoon = slice(0, 16)
locations = []
plate = pd.DataFrame(s[spoon])
for word in WORDS:
  locations += find_word_in_plate(word, plate)
table = serve_soup(plate, locations)
table
# Out:
# CPU times: user 166 ms, sys: 169 µs, total: 167 ms
# Wall time: 167 ms
# <style type="text/css">
# #T_c65bb_row0_col0, #T_c65bb_row0_col1, #T_c65bb_row0_col2, #T_c65bb_row0_col3, #T_c65bb_row0_col4, #T_c65bb_row0_col5, #T_c65bb_row0_col6, #T_c65bb_row0_col7, #T_c65bb_row0_col8, #T_c65bb_row0_col9, #T_c65bb_row0_col10, #T_c65bb_row0_col11, #T_c65bb_row0_col12, #T_c65bb_row0_col13, #T_c65bb_row0_col14, #T_c65bb_row0_col15, #T_c65bb_row1_col0, #T_c65bb_row1_col1, #T_c65bb_row1_col2, #T_c65bb_row1_col3, #T_c65bb_row1_col4, #T_c65bb_row1_col5, #T_c65bb_row1_col6, #T_c65bb_row1_col8, #T_c65bb_row1_col9, #T_c65bb_row1_col10, #T_c65bb_row1_col11, #T_c65bb_row1_col12, #T_c65bb_row1_col13, #T_c65bb_row1_col14, #T_c65bb_row1_col15, #T_c65bb_row2_col0, #T_c65bb_row2_col1, #T_c65bb_row2_col2, #T_c65bb_row2_col3, #T_c65bb_row2_col4, #T_c65bb_row2_col5, #T_c65bb_row2_col6, #T_c65bb_row2_col8, #T_c65bb_row2_col9, #T_c65bb_row2_col10, #T_c65bb_row2_col11, #T_c65bb_row2_col12, #T_c65bb_row2_col13, #T_c65bb_row2_col14, #T_c65bb_row2_col15, #T_c65bb_row3_col0, #T_c65bb_row3_col1, #T_c65bb_row3_col2, #T_c65bb_row3_col3, #T_c65bb_row3_col4, #T_c65bb_row3_col5, #T_c65bb_row3_col6, #T_c65bb_row3_col8, #T_c65bb_row3_col9, #T_c65bb_row3_col10, #T_c65bb_row3_col11, #T_c65bb_row3_col12, #T_c65bb_row3_col13, #T_c65bb_row3_col14, #T_c65bb_row3_col15, #T_c65bb_row4_col0, #T_c65bb_row4_col1, #T_c65bb_row4_col2, #T_c65bb_row4_col3, #T_c65bb_row4_col4, #T_c65bb_row4_col5, #T_c65bb_row4_col6, #T_c65bb_row4_col8, #T_c65bb_row4_col9, #T_c65bb_row4_col10, #T_c65bb_row4_col11, #T_c65bb_row4_col12, #T_c65bb_row4_col13, #T_c65bb_row4_col14, #T_c65bb_row4_col15, #T_c65bb_row5_col0, #T_c65bb_row5_col1, #T_c65bb_row5_col2, #T_c65bb_row5_col3, #T_c65bb_row5_col4, #T_c65bb_row5_col5, #T_c65bb_row5_col6, #T_c65bb_row5_col7, #T_c65bb_row5_col8, #T_c65bb_row5_col9, #T_c65bb_row5_col10, #T_c65bb_row5_col11, #T_c65bb_row5_col12, #T_c65bb_row5_col13, #T_c65bb_row5_col14, #T_c65bb_row5_col15, #T_c65bb_row6_col0, #T_c65bb_row6_col1, #T_c65bb_row6_col2, #T_c65bb_row6_col3, #T_c65bb_row6_col4, #T_c65bb_row6_col5, #T_c65bb_row6_col6, #T_c65bb_row6_col7, #T_c65bb_row6_col8, #T_c65bb_row6_col9, #T_c65bb_row6_col10, #T_c65bb_row6_col11, #T_c65bb_row6_col12, #T_c65bb_row6_col13, #T_c65bb_row6_col14, #T_c65bb_row6_col15, #T_c65bb_row7_col0, #T_c65bb_row7_col1, #T_c65bb_row7_col2, #T_c65bb_row7_col3, #T_c65bb_row7_col4, #T_c65bb_row7_col5, #T_c65bb_row7_col6, #T_c65bb_row7_col7, #T_c65bb_row7_col8, #T_c65bb_row7_col9, #T_c65bb_row7_col10, #T_c65bb_row7_col11, #T_c65bb_row7_col12, #T_c65bb_row7_col13, #T_c65bb_row7_col14, #T_c65bb_row7_col15, #T_c65bb_row8_col0, #T_c65bb_row8_col1, #T_c65bb_row8_col2, #T_c65bb_row8_col3, #T_c65bb_row8_col4, #T_c65bb_row8_col5, #T_c65bb_row8_col6, #T_c65bb_row8_col7, #T_c65bb_row8_col8, #T_c65bb_row8_col9, #T_c65bb_row8_col10, #T_c65bb_row8_col11, #T_c65bb_row8_col12, #T_c65bb_row8_col13, #T_c65bb_row8_col14, #T_c65bb_row8_col15, #T_c65bb_row9_col0, #T_c65bb_row9_col1, #T_c65bb_row9_col2, #T_c65bb_row9_col3, #T_c65bb_row9_col4, #T_c65bb_row9_col5, #T_c65bb_row9_col6, #T_c65bb_row9_col7, #T_c65bb_row9_col8, #T_c65bb_row9_col9, #T_c65bb_row9_col10, #T_c65bb_row9_col11, #T_c65bb_row9_col12, #T_c65bb_row9_col13, #T_c65bb_row9_col14, #T_c65bb_row9_col15, #T_c65bb_row10_col0, #T_c65bb_row10_col1, #T_c65bb_row10_col2, #T_c65bb_row10_col3, #T_c65bb_row10_col4, #T_c65bb_row10_col5, #T_c65bb_row10_col6, #T_c65bb_row10_col7, #T_c65bb_row10_col8, #T_c65bb_row10_col9, #T_c65bb_row10_col10, #T_c65bb_row10_col11, #T_c65bb_row10_col12, #T_c65bb_row10_col13, #T_c65bb_row10_col14, #T_c65bb_row10_col15, #T_c65bb_row11_col0, #T_c65bb_row11_col1, #T_c65bb_row11_col2, #T_c65bb_row11_col3, #T_c65bb_row11_col4, #T_c65bb_row11_col5, #T_c65bb_row11_col6, #T_c65bb_row11_col7, #T_c65bb_row11_col8, #T_c65bb_row11_col9, #T_c65bb_row11_col10, #T_c65bb_row11_col11, #T_c65bb_row11_col12, #T_c65bb_row11_col13, #T_c65bb_row11_col14, #T_c65bb_row11_col15, #T_c65bb_row12_col0, #T_c65bb_row12_col1, #T_c65bb_row12_col2, #T_c65bb_row12_col3, #T_c65bb_row12_col4, #T_c65bb_row12_col5, #T_c65bb_r ...
#   text-align: center;
# }
# #T_c65bb_row1_col7, #T_c65bb_row2_col7, #T_c65bb_row3_col7, #T_c65bb_row4_col7, #T_c65bb_row14_col8, #T_c65bb_row14_col9, #T_c65bb_row14_col10, #T_c65bb_row14_col11, #T_c65bb_row15_col1, #T_c65bb_row15_col2, #T_c65bb_row15_col3, #T_c65bb_row15_col4, #T_c65bb_row15_col5, #T_c65bb_row15_col6 {
#   text-align: center;
#   background: yellow;
# }
# </style>
# <table id="T_c65bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c65bb_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c65bb_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c65bb_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c65bb_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c65bb_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_c65bb_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_c65bb_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_c65bb_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_c65bb_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_c65bb_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_c65bb_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_c65bb_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_c65bb_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_c65bb_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_c65bb_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_c65bb_level0_col15" class="col_heading level0 col15" >15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c65bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c65bb_row0_col0" class="data row0 col0" >I</td>
#       <td id="T_c65bb_row0_col1" class="data row0 col1" >K</td>
#       <td id="T_c65bb_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_c65bb_row0_col3" class="data row0 col3" >J</td>
#       <td id="T_c65bb_row0_col4" class="data row0 col4" >F</td>
#       <td id="T_c65bb_row0_col5" class="data row0 col5" >B</td>
#       <td id="T_c65bb_row0_col6" class="data row0 col6" >J</td>
#       <td id="T_c65bb_row0_col7" class="data row0 col7" >U</td>
#       <td id="T_c65bb_row0_col8" class="data row0 col8" >I</td>
#       <td id="T_c65bb_row0_col9" class="data row0 col9" >M</td>
#       <td id="T_c65bb_row0_col10" class="data row0 col10" >N</td>
#       <td id="T_c65bb_row0_col11" class="data row0 col11" >M</td>
#       <td id="T_c65bb_row0_col12" class="data row0 col12" >I</td>
#       <td id="T_c65bb_row0_col13" class="data row0 col13" >P</td>
#       <td id="T_c65bb_row0_col14" class="data row0 col14" >V</td>
#       <td id="T_c65bb_row0_col15" class="data row0 col15" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_c65bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6

# %% [markdown]
# ## Deliverable 2
# The function that finds words in the puzzle is a very slow function with absolutely no optimization. Create a 2-dimensional soup of size 512 x 512. Insert the word "MINING" and measure the time to find the word using the provided function (find_word_in_plate).
#
# Create a new optimized function to find words:
# ```
# find_word_in_plate_faster(word, soup_plate)
# ```
# This new function should include at least one optimization that makes finding the word faster.
#
# Describe the optimization and how it helps finding words faster.
# Run the find_word_in_plate_faster function in the 512x512 puzzle above and report the new time.

# %%
def find_word_in_plate_faster(word, soup_plate):
  '''Find a word faster in a 2-dimensional Pandas DataFrame'''
  result = []
  word_start = word[0]

  for irow, row in soup_plate.iterrows():
    if word_start in row.values:
      for icol, cell in row.items():
        if cell == word_start:
          r = is_word_at_location(word, irow, icol, soup_plate)
          if r == "h":
            result.append(([irow], slice(icol, icol + len(word)-1)))
          elif r == 'v':
            result.append((slice(irow, irow + len(word)-1), [icol]))

  return result

# %% [markdown]
# **The Optimization involved in the method find_word_in_plate_faster(word, soup_plate) is the reduction of unnecessary iterations and checks. This Optimization is achieved by checking the presence of the first letter of the target word in soup_plate before trying to find the word. In this way, it is possible to skip rows and columns that do not contain the first letter, thereby reducing the number of iterations.**

# %%
dimensions = (512, 512)
s = create_soup(dimensions, WORD, ALPHABET)
sl = slice(0, 512)
spoon = (sl, sl)
plate = pd.DataFrame(s[spoon])

# To Measure the time taken for the original function
start_time = np.datetime64('now')
words = find_word_in_plate(WORD, plate)
end_time = np.datetime64('now')
elapsed_time_original = end_time - start_time

# To Measure the time taken for the optimized function
start_time = np.datetime64('now')
words_faster = find_word_in_plate_faster(WORD, plate)
end_time = np.datetime64('now')
elapsed_time_optimized = end_time - start_time

print("Word searched in both the functions is:", WORD)
print("Time taken by original function:", elapsed_time_original)
print("Time taken by optimized function:", elapsed_time_optimized)
# Out:
# Word searched in both the functions is: MINING
# Time taken by original function: 86 seconds
# Time taken by optimized function: 4 seconds
